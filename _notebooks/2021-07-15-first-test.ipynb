# %% [markdown]
# This is my first try of using Google Colab. Let's see what we can achieve :)
#
# Let's start with some initial stuff.

# %%
no1 = 10
no2 = 1222

calc = no1 / no2 + no1

print(calc)
# Out:
# 10.008183306055647
